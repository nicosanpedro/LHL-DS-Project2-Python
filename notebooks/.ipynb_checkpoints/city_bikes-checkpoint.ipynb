# %%
import requests
import os

import pandas as pd
import numpy as np

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]

# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
city = "toronto"
url = "http://api.citybik.es/v2/networks/" + city

result = requests.get(url)
result
# Out:
# <Response [200]>

# %%
toronto_bikes = result.json()

# %%
locations = []

stations = toronto_bikes['network']['stations']
for station in stations:
    lat = station['latitude']
    lon = station['longitude']
    locations.append((lat, lon))

print(len(locations))
# Out:
# 30

# %%
city = "charlotte"
url = "http://api.citybik.es/v2/networks/" + city

result = requests.get(url)
result.json()
# Out:
# {'network': {'company': ['BCycle, LLC'],
#   'gbfs_href': 'https://gbfs.bcycle.com/bcycle_charlotte/gbfs.json',
#   'href': '/v2/networks/charlotte',
#   'id': 'charlotte',
#   'location': {'city': 'Charlotte, NC',
#    'country': 'US',
#    'latitude': 35.22716,
#    'longitude': -80.83855},
#   'name': 'Charlotte B-cycle',
#   'stations': [{'empty_slots': 4,
#     'extra': {'address': '1201 Central Ave',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4124&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4124&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4124'},
#     'free_bikes': 5,
#     'id': 'd65a9eac29b3b517ffeef4a25561eeaa',
#     'latitude': 35.2214,
#     'longitude': -80.8183,
#     'name': '1201 Central Ave',
#     'timestamp': '2023-09-05T00:29:04.655000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': '150 W 9th st',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4125&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4125&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4125'},
#     'free_bikes': 6,
#     'id': '868bc6f15420051d560214d4b23106b8',
#     'latitude': 35.2316,
#     'longitude': -80.8383,
#     'name': 'Skyhouse',
#     'timestamp': '2023-09-05T00:29:04.655000Z'},
#    {'empty_slots': 6,
#     'extra': {'address': '400 E. Stonewall St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4123&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4123&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4123'},
#     'free_bikes': 5,
#     'id': '4f08e3a11ee26cd8d1eb5df23bfa90a7',
#     'latitude': 35.2213,
#     'longitude': -80.8463,
#     'name': 'Whole Foods',
#     'timestamp': '2023-09-05T00:29:04.656000Z'},
#    {'empty_slots': 9,
#     'extra': {'address': '430 S. Tryon St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2114&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2114&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2114'},
#     'free_bikes': 4,
#     'id': '2447765515d9a3929580c2e4c65d8509',
#     'latitude': 35.22473,
#     'longitude': -80.84805,
#     'name': 'Levine Ave. of the Arts',
#     'timestamp': '2023-09-05T00:29:04.657000Z'},
#    {'empty_slots': 6,
#     'extra': {'address': '320 E. 9th St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2116&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2116&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2116'},
#     'free_bikes': 5,
#     'id': '4726f7c8f050c0635fa8573a98b85d51',
#     'latitude': 35.22853,
#     'longitude': -80.83482,
#     'name': 'UNC Charlotte Uptown',
#     'timestamp': '2023-09-05T00:29:04.658000Z'},
#    {'empty_slots': 13,
#     'extra': {'address': '1509 Camden Rd.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2113&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2113&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2113'},
#     'free_bikes': 1,
#     'id': 'd449c64026e3720c64752f4eab196ef7',
#     'latitude': 35.21573,
#     'longitude': -80.85543,
#     'name': 'Bland St.',
#     'timestamp': '2023-09-05T00:29:04.659000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '1140 Elizabeth Ave.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2112&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2112&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2112'},
#     'free_bikes': 4,
#     'id': '34fc984689daaed7aa0b4ad99e40c53c',
#     'latitude': 35.21797,
#     'longitude': -80.83199,
#     'name': 'Kings Dr./CPCC',
#     'timestamp': '2023-09-05T00:29:04.659000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '1601 Mockingbird Ln.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2102&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2102&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2102'},
#     'free_bikes': 3,
#     'id': '512683e837bfcad1757c676216ea88e2',
#     'latitude': 35.16703,
#     'longitude': -80.84912,
#     'name': 'Montford',
#     'timestamp': '2023-09-05T00:29:04.660000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '1532 Elizabeth Ave.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2119&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2119&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2119'},
#     'free_bikes': 6,
#     'id': '2aef482aeaccf9d52309c1e0ea6338fb',
#     'latitude': 35.21382,
#     'longitude': -80.82683,
#     'name': 'Elizabeth Ave./Presbyterian Hospital',
#     'timestamp': '2023-09-05T00:29:04.660000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': '301 S. Tryon Street',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2118&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2118&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2118'},
#     'free_bikes': 5,
#     'id': '3ca9a1563d90ac89a2d345284045c844',
#     'latitude': 35.22505,
#     'longitude': -80.84526,
#     'name': 'Tryon & 3rd',
#     'timestamp': '2023-09-05T00:29:04.661000Z'},
#    {'empty_slots': 6,
#     'extra': {'address': '282 W. Martin Luther King Jr. Blvd.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2650&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2650&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2650'},
#     'free_bikes': 7,
#     'id': '75d3cdbfff0e2d384810364005160ae8',
#     'latitude': 35.2265,
#     'longitude': -80.84809,
#     'name': 'Romare Bearden Park',
#     'timestamp': '2023-09-05T00:29:04.662000Z'},
#    {'empty_slots': 6,
#     'extra': {'address': '725 W. 4th St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2651&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2651&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2651'},
#     'free_bikes': 3,
#     'id': '33e0f563f0b7335117de223d82257884',
#     'latitude': 35.23192,
#     'longitude': -80.85091,
#     'name': '4th & Cedar',
#     'timestamp': '2023-09-05T00:29:04.664000Z'},
#    {'empty_slots': 8,
#     'extra': {'address': '1400 Harding Place',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_3356&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_3356&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_3356'},
#     'free_bikes': 5,
#     'id': '423915c48ac98fa23377ee159d3b92eb',
#     'latitude': 35.20708,
#     'longitude': -80.83694,
#     'name': 'Berkshire Dilworth ',
#     'timestamp': '2023-09-05T00:29:04.665000Z'},
#    {'empty_slots': 8,
#     'extra': {'address': '300 E. 7th Street',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2093&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2093&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2093'},
#     'free_bikes': 7,
#     'id': '2de329f573114cb42f978fb55396945f',
#     'latitude': 35.22732,
#     'longitude': -80.83827,
#     'name': '7th St. Public Market',
#     'timestamp': '2023-09-05T00:29:04.666000Z'},
#    {'empty_slots': 13,
#     'extra': {'address': '129 New Bern St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2398&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2398&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2398'},
#     'free_bikes': 2,
#     'id': '9c31f7e62a4f97728f3c1d6332ceca2c',
#     'latitude': 35.20028,
#     'longitude': -80.86884,
#     'name': 'New Bern',
#     'timestamp': '2023-09-05T00:29:04.666000Z'},
#    {'empty_slots': 8,
#     'extra': {'address': '898 W. Trade Street',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2106&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2106&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2106'},
#     'free_bikes': 5,
#     'id': 'e3cf0d16455f23c86ad01148e56f65d9',
#     'latitude': 35.23411,
#     'longitude': -80.85116,
#     'name': 'Gateway Village',
#     'timestamp': '2023-09-05T00:29:04.667000Z'},
#    {'empty_slots': 9,
#     'extra': {'address': '1305 Central Avenue',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_3617&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_3617&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_3617'},
#     'free_bikes': 5,
#     'id': '1696d3bd3faf1e524205768cf6c081c8',
#     'latitude': 35.22101,
#     'longitude': -80.81633,
#     'name': 'ONE305',
#     'timestamp': '2023-09-05T00:29:04.671000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '600 E. 4th Street',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2105&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2105&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2105'},
#     'free_bikes': 5,
#     'id': '5c8bb7200363d7da10fd65a05dacc825',
#     'latitude': 35.22169,
#     'longitude': -80.83905,
#     'name': 'Government Center',
#     'timestamp': '2023-09-05T00:29:04.672000Z'},
#    {'empty_slots': 8,
#     'extra': {'address': '410 W. 6th St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2103&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2103&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2103'},
#     'free_bikes': 6,
#     'id': 'd262256cb2207723c1637cd83807ab91',
#     'latitude': 35.23152,
#     'longitude': -80.84396,
#     'name': '6th & Pine',
#     'timestamp': '2023-09-05T00:29:04.674000Z'},
#    {'empty_slots': 6,
#     'extra': {'address': '1101 Blythe Blvd.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2100&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2100&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2100'},
#     'free_bikes': 3,
#     'id': 'ea0f1cb84167233d2508616d8be7b80a',
#     'latitude': 35.20373,
#     'longitude': -80.83734,
#     'name': 'Carolinas Medical Center',
#     'timestamp': '2023-09-05T00:29:04.675000Z'},
#    {'empty_slots': 10,
#     'extra': {'address': '2399 Freedom Park Service Rd.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2101&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2101&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2101'},
#     'free_bikes': 12,
#     'id': 'a8c100ef7a8967c59e77b09b4c38a3dc',
#     'latitude': 35.19034,
#     'longitude': -80.84509,
#     'name': 'Freedom Park',
#     'timestamp': '2023-09-05T00:29:04.676000Z'},
#    {'empty_slots': 3,
#     'extra': {'address': '722 Charlottetowne Ave.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2099&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2099&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2099'},
#     'free_bikes': 3,
#     'id': 'aeb20f1bc74dd309c3386dae05324335',
#     'latitude': 35.21206,
#     'longitude': -80.83546,
#     'name': 'Metropolitan',
#     'timestamp': '2023-09-05T00:29:04.677000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': '941 S. Tryon St. ',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2649&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2649&platform=iOS'},
#      'renting': 0,
#      'returning': 0,
#      'uid': 'bcycle_charlotte_2649'},
#     'free_bikes': 4,
#     'id': '26f7d8baccb36f6b9653ea8b15be2849',
#     'latitude': 35.22109,
#     'longitude': -80.85097,
#     'name': 'S. Tryon & Morehead',
#     'timestamp': '2023-09-05T00:29:04.678000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '501 S. College Street',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2108&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2108&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2108'},
#     'free_bikes': 7,
#     'id': '8f6b946b7935855496a01cd7469c94bd',
#     'latitude': 35.22314,
#     'longitude': -80.8456,
#     'name': 'Convention Center',
#     'timestamp': '2023-09-05T00:29:04.678000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': '1601 W Trade st',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2115&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2115&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2115'},
#     'free_bikes': 4,
#     'id': '4841746cc17f2a60de11dcbfd9181ca7',
#     'latitude': 35.24012,
#     'longitude': -80.85859,
#     'name': 'S Bruns & Trade',
#     'timestamp': '2023-09-05T00:29:04.657000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': 'Camp',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4652&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4652&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4652'},
#     'free_bikes': 4,
#     'id': '362824da5e66f25b21e1050479e53aff',
#     'latitude': 35.24619,
#     'longitude': -80.83385,
#     'name': 'Camp North End (public)',
#     'timestamp': '2023-09-05T00:29:04.653000Z'},
#    {'empty_slots': 4,
#     'extra': {'address': 'Skyhouse',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4648&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4648&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4648'},
#     'free_bikes': 3,
#     'id': 'afdcd0d4cb0aebb89b50639c00bd9b6e',
#     'latitude': 35.22926,
#     'longitude': -80.85508,
#     'name': 'Community Matters Cafe',
#     'timestamp': '2023-09-05T00:29:04.662000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': 'Seigle',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4647&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4647&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4647'},
#     'free_bikes': 4,
#     'id': '54102f7a1cf9210f1a71c356d9d9ad1d',
#     'latitude': 35.22561,
#     'longitude': -80.82504,
#     'name': 'Seigle - New',
#     'timestamp': '2023-09-05T00:29:04.663000Z'},
#    {'empty_slots': 5,
#     'extra': {'address': '1422 S. Tryon St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4646&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_4646&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_4646'},
#     'free_bikes': 3,
#     'id': 'cf00883757fcea0369912f5a9996f835',
#     'latitude': 35.21686,
#     'longitude': -80.85558,
#     'name': 'New Railyard',
#     'timestamp': '2023-09-05T00:29:04.664000Z'},
#    {'empty_slots': 7,
#     'extra': {'address': '102 E. Trade St.',
#      'last_updated': 1693873744,
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2094&platform=android',
#       'ios': 'https://www.bcycle.com/applink?system_id=bcycle_charlotte&station_id=bcycle_charlotte_2094&platform=iOS'},
#      'renting': 1,
#      'returning': 1,
#      'uid': 'bcycle_charlotte_2094'},
#     'free_bikes': 6,
#     'id': '3744c530b95ca40c43cf584830be4fe2',
#     'latitude': 35.22681,
#     'longitude': -80.84278,
#     'name': 'Trade & Tryon',
#     'timestamp': '2023-09-05T00:29:04.673000Z'}]}}

# %% [raw]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %% [markdown]
# Put your parsed results into a DataFrame.
